# %%
#import libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error as MAE
import xgboost
import tensorflow as tf

# %%
df = pd.read_csv("gas_turbines.csv")

# %%
df
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# ...

# %%
df.shape
# Out:
# (15039, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
df.head()
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %%
df.describe()
# Out:
#                  AT           AP            AH          AFDP          GTEP  \
# count  15039.000000  15039.00000  15039.000000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174      4.200294     25.419061
# std        7.574323      6.41076     13.793439      0.760197      4.173916
# min        0.522300    985.85000     30.344000      2.087400     17.878000
# 25%       11.408000   1008.90000     69.750000      3.723900     23.294000
# 50%       18.186000   1012.80000     82.266000      4.186200     25.082000
# 75%       23.862500   1016.90000     90.043500      4.550900     27.184000
# max       34.929000   1034.20000    100.200000      7.610600     37.402000
#
#                 TIT           TAT           TEY           CDP            CO  \
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000
# mean    1083.798770    545.396183    134.188464     12.102353      1.972499
# ...

# %%
shuffled_df=df.sample(frac=1,ignore_index=True)

# %%
dataset=np.array(shuffled_df)
dataset.shape
# Out:
# (15039, 11)

# %%
X = dataset[:,:9]
y = dataset[:,9:]
y_co = y[:,0]
y_nox = y[:,1]
X.shape , y.shape , y_co.shape , y_nox.shape
# Out:
# ((15039, 9), (15039, 2), (15039,), (15039,))

# %%
#generating Train, Test and Valid dataset and checking their shapes

X_train_full , X_test , y_train_full , y_test = train_test_split(X , y, train_size=0.85)
X_train , X_valid , y_train , y_valid = train_test_split(X_train_full , y_train_full)

X_train.shape, X_valid.shape, X_test.shape
# Out:
# ((9587, 9), (3196, 9), (2256, 9))

# %%
# creating "xgboost model" with defualt hyperparameters
# creating scaler using StandardScaler to normalize data

model_co = xgboost.XGBRegressor()
model_nox = xgboost.XGBRegressor()
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_valid_scaled = scaler.transform(X_valid)
X_test_scaled = scaler.transform(X_test)

# %%
# Separeting labels to use each one in individual training model
y_co_train = y_train[:,0]
y_co_valid = y_valid[:,0]
y_co_test = y_test[:,0]

y_nox_train = y_train[:,1]
y_nox_valid = y_valid[:,1]
y_nox_test = y_test[:,1]

# %%
y_co_train.shape
# Out:
# (9587,)

# %%
model_co.fit(X_train_scaled, y_co_train, eval_set=[(X_valid_scaled, y_co_valid)], early_stopping_rounds=5)
# Out:
# [0]	validation_0-rmse:2.39755
# [1]	validation_0-rmse:2.09173
# [2]	validation_0-rmse:1.86887
# [3]	validation_0-rmse:1.72774
# [4]	validation_0-rmse:1.61801
# [5]	validation_0-rmse:1.55502
# [6]	validation_0-rmse:1.49415
# [7]	validation_0-rmse:1.45672
# [8]	validation_0-rmse:1.42547
# [9]	validation_0-rmse:1.40942
# [10]	validation_0-rmse:1.39374
# [11]	validation_0-rmse:1.38806
# [12]	validation_0-rmse:1.37757
# [13]	validation_0-rmse:1.37234
# [14]	validation_0-rmse:1.36617
# [15]	validation_0-rmse:1.36096
# [16]	validation_0-rmse:1.35910
# [17]	validation_0-rmse:1.36177
# [18]	validation_0-rmse:1.36130
# [19]	validation_0-rmse:1.35835
# [20]	validation_0-rmse:1.35687
# [21]	validation_0-rmse:1.35706
# [22]	validation_0-rmse:1.35686
# [23]	validation_0-rmse:1.35564
# [24]	validation_0-rmse:1.35520
# [25]	validation_0-rmse:1.35543
# [26]	validation_0-rmse:1.35298
# [27]	validation_0-rmse:1.35494
# [28]	validation_0-rmse:1.35440
# [29]	validation_0-rmse:1.35214
# ...

# %%
model_nox.fit(X_train_scaled, y_nox_train, eval_set=[(X_valid_scaled, y_nox_valid)], early_stopping_rounds=5)
# Out:
# [0]	validation_0-rmse:48.23486
# [1]	validation_0-rmse:33.99964
# [2]	validation_0-rmse:24.06517
# [3]	validation_0-rmse:17.16102
# [4]	validation_0-rmse:12.45800
# [5]	validation_0-rmse:9.25037
# [6]	validation_0-rmse:7.14273
# [7]	validation_0-rmse:5.80650
# [8]	validation_0-rmse:5.00444
# [9]	validation_0-rmse:4.55362
# [10]	validation_0-rmse:4.29178
# [11]	validation_0-rmse:4.13438
# [12]	validation_0-rmse:4.05069
# [13]	validation_0-rmse:3.98612
# [14]	validation_0-rmse:3.95741
# [15]	validation_0-rmse:3.93699
# [16]	validation_0-rmse:3.90628
# [17]	validation_0-rmse:3.88414
# [18]	validation_0-rmse:3.87817
# [19]	validation_0-rmse:3.86288
# [20]	validation_0-rmse:3.85128
# [21]	validation_0-rmse:3.83613
# [22]	validation_0-rmse:3.83268
# [23]	validation_0-rmse:3.83208
# [24]	validation_0-rmse:3.80800
# [25]	validation_0-rmse:3.80287
# [26]	validation_0-rmse:3.79541
# [27]	validation_0-rmse:3.79440
# [28]	validation_0-rmse:3.79592
# [29]	validation_0-rmse:3.79629
# ...

# %%
y_co_pred = model_co.predict(X_test_scaled)
y_nox_pred = model_nox.predict(X_test_scaled)

# %%
# Evaluting models

print('Mean Absolute Error for CO prediction: ',MAE(y_co_test, y_co_pred))
print('Mean Absolute Error for Nox prediction: ',MAE(y_nox_test, y_nox_pred))
# Out:
# Mean Absolute Error for CO prediction:  0.46753643388594956
# Mean Absolute Error for Nox prediction:  2.4108946799014483
